# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
data = pd.read_csv('TSLA.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# %%
prices = data['Close'].values.reshape(-1, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
prices_scaled = scaler.fit_transform(prices)

window_size = 30

# %%
train_size = int(len(prices_scaled) * 0.8)
train_data, test_data = prices_scaled[:train_size], prices_scaled[train_size:]

# %%
def create_sequences(data, window_size):
    sequences = []
    for i in range(len(data) - window_size):
        sequence = data[i:i + window_size]
        sequences.append(sequence)
    return np.array(sequences)

train_sequences = create_sequences(train_data, window_size)
test_sequences = create_sequences(test_data, window_size)

# %%
X_train, y_train = train_sequences[:, :-1], train_sequences[:, -1]
X_test, y_test = test_sequences[:, :-1], test_sequences[:, -1]

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(window_size - 1, 1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
epochs = 100
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 60/60 [==============================] - 9s 67ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 2/100
# 60/60 [==============================] - 3s 43ms/step - loss: 2.6906e-04 - val_loss: 0.0014
# Epoch 3/100
# 60/60 [==============================] - 3s 42ms/step - loss: 2.5746e-04 - val_loss: 0.0015
# Epoch 4/100
# 60/60 [==============================] - 3s 43ms/step - loss: 2.6301e-04 - val_loss: 0.0012
# Epoch 5/100
# 60/60 [==============================] - 3s 42ms/step - loss: 2.3301e-04 - val_loss: 0.0012
# Epoch 6/100
# 60/60 [==============================] - 2s 41ms/step - loss: 2.1998e-04 - val_loss: 0.0011
# Epoch 7/100
# 60/60 [==============================] - 2s 41ms/step - loss: 2.1996e-04 - val_loss: 0.0011
# Epoch 8/100
# 60/60 [==============================] - 2s 40ms/step - loss: 1.9796e-04 - val_loss: 9.9775e-04
# Epoch 9/100
# 60/60 [==============================] - 2s 40ms/step - loss: 1.8582e-04 - val_loss: 0.0011
# Epoch 10/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.9911e-04 - val_loss: 8.1079e-04
# Epoch 11/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.7152e-04 - val_loss: 8.3755e-04
# Epoch 12/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.6151e-04 - val_loss: 7.0606e-04
# Epoch 13/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.6050e-04 - val_loss: 6.7793e-04
# Epoch 14/100
# 60/60 [==============================] - 3s 42ms/step - loss: 1.4794e-04 - val_loss: 6.5758e-04
# Epoch 15/100
# 60/60 [==============================] - 3s 42ms/step - loss: 1.4499e-04 - val_loss: 6.4990e-04
# Epoch 16/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.3415e-04 - val_loss: 6.2686e-04
# Epoch 17/100
# 60/60 [==============================] - 2s 42ms/step - loss: 1.2808e-04 - val_loss: 5.8080e-04
# Epoch 18/100
# 60/60 [==============================] - 3s 42ms/step - loss: 1.3759e-04 - val_loss: 6.7412e-04
# Epoch 19/100
# 60/60 [==============================] - 2s 40ms/step - loss: 1.3501e-04 - val_loss: 5.4084e-04
# Epoch 20/100
# 60/60 [==============================] - 3s 42ms/step - loss: 1.2710e-04 - val_loss: 5.4792e-04
# Epoch 21/100
# 60/60 [==============================] - 2s 42ms/step - loss: 1.2246e-04 - val_loss: 5.6763e-04
# Epoch 22/100
# 60/60 [==============================] - 2s 40ms/step - loss: 1.1804e-04 - val_loss: 4.9602e-04
# Epoch 23/100
# 60/60 [==============================] - 2s 40ms/step - loss: 1.1423e-04 - val_loss: 5.0166e-04
# Epoch 24/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.2489e-04 - val_loss: 5.9705e-04
# Epoch 25/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.0731e-04 - val_loss: 4.4580e-04
# Epoch 26/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.0194e-04 - val_loss: 4.7061e-04
# Epoch 27/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.1611e-04 - val_loss: 4.3075e-04
# Epoch 28/100
# 60/60 [==============================] - 2s 42ms/step - loss: 1.0483e-04 - val_loss: 4.2763e-04
# Epoch 29/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.0084e-04 - val_loss: 4.2475e-04
# Epoch 30/100
# 60/60 [==============================] - 2s 41ms/step - loss: 9.6844e-05 - val_loss: 4.4937e-04
# Epoch 31/100
# 60/60 [==============================] - 2s 41ms/step - loss: 9.9547e-05 - val_loss: 4.0837e-04
# Epoch 32/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.0052e-04 - val_loss: 4.0989e-04
# Epoch 33/100
# 60/60 [==============================] - 2s 41ms/step - loss: 8.7055e-05 - val_loss: 3.5905e-04
# Epoch 34/100
# 60/60 [==============================] - 2s 41ms/step - loss: 1.1687e-04 - val_loss: 3.6753e-04
# Epoch 35/100
# 60/60 [==============================] - 2s 41ms/step - loss: 9.0163e-05 - val_loss: 5.6673e-04
# Epoch 36/100
# 60/60 [==============================] - 2s 41ms/step - loss: 8.3711e-05 - val_loss: 3.4549e-04
# Epoch 37/100
# 60/60 [==============================] - 2s 41ms/step - loss: 8.5563e-05 - val_loss: 5.1709e-04
# Epoch 38/100
# 60/60 [==============================] - 2s 41ms/step - loss: 8.6316e-05 - val_loss: 3.6704e-04
# Epoch 39/100
# 60/60 [==============================] - 2s 41ms/step - loss: 8.0469e-05 - val_loss: 3.5335e-04
# Epoch 40/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.7527e-05 - val_loss: 3.1513e-04
# Epoch 41/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.9106e-05 - val_loss: 3.5318e-04
# Epoch 42/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.8677e-05 - val_loss: 3.0563e-04
# Epoch 43/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.5620e-05 - val_loss: 3.0225e-04
# Epoch 44/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.1869e-05 - val_loss: 2.9268e-04
# Epoch 45/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.2780e-05 - val_loss: 3.2150e-04
# Epoch 46/100
# 60/60 [==============================] - 2s 42ms/step - loss: 6.9926e-05 - val_loss: 3.1805e-04
# Epoch 47/100
# 60/60 [==============================] - 3s 42ms/step - loss: 7.1238e-05 - val_loss: 2.7884e-04
# Epoch 48/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.3279e-05 - val_loss: 2.9192e-04
# Epoch 49/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.1973e-05 - val_loss: 3.2542e-04
# Epoch 50/100
# 60/60 [==============================] - 2s 41ms/step - loss: 6.6483e-05 - val_loss: 2.8241e-04
# Epoch 51/100
# 60/60 [==============================] - 2s 42ms/step - loss: 7.2567e-05 - val_loss: 2.5959e-04
# Epoch 52/100
# 60/60 [==============================] - 2s 41ms/step - loss: 6.3668e-05 - val_loss: 2.6704e-04
# Epoch 53/100
# 60/60 [==============================] - 2s 41ms/step - loss: 6.7290e-05 - val_loss: 2.8661e-04
# Epoch 54/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.8156e-05 - val_loss: 3.2801e-04
# Epoch 55/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.8803e-05 - val_loss: 2.8938e-04
# Epoch 56/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.9174e-05 - val_loss: 2.4445e-04
# Epoch 57/100
# 60/60 [==============================] - 2s 40ms/step - loss: 6.4081e-05 - val_loss: 2.5020e-04
# Epoch 58/100
# 60/60 [==============================] - 2s 42ms/step - loss: 6.6719e-05 - val_loss: 2.4438e-04
# Epoch 59/100
# 60/60 [==============================] - 2s 42ms/step - loss: 5.7416e-05 - val_loss: 2.3924e-04
# Epoch 60/100
# 60/60 [==============================] - 2s 41ms/step - loss: 7.3708e-05 - val_loss: 3.1693e-04
# Epoch 61/100
# 60/60 [==============================] - 2s 40ms/step - loss: 7.5958e-05 - val_loss: 2.4292e-04
# Epoch 62/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.4710e-05 - val_loss: 2.4683e-04
# Epoch 63/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.7479e-05 - val_loss: 2.4398e-04
# Epoch 64/100
# 60/60 [==============================] - 2s 41ms/step - loss: 6.1215e-05 - val_loss: 2.3863e-04
# Epoch 65/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.9074e-05 - val_loss: 2.3597e-04
# Epoch 66/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.4166e-05 - val_loss: 2.2130e-04
# Epoch 67/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.3524e-05 - val_loss: 2.1819e-04
# Epoch 68/100
# 60/60 [==============================] - 2s 40ms/step - loss: 4.9905e-05 - val_loss: 2.1272e-04
# Epoch 69/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.2884e-05 - val_loss: 2.1942e-04
# Epoch 70/100
# 60/60 [==============================] - 2s 40ms/step - loss: 4.8907e-05 - val_loss: 2.2520e-04
# Epoch 71/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.0762e-05 - val_loss: 2.2944e-04
# Epoch 72/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.9269e-05 - val_loss: 2.1347e-04
# Epoch 73/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.6952e-05 - val_loss: 2.1956e-04
# Epoch 74/100
# 60/60 [==============================] - 2s 40ms/step - loss: 4.5719e-05 - val_loss: 2.0903e-04
# Epoch 75/100
# 60/60 [==============================] - 2s 40ms/step - loss: 4.6911e-05 - val_loss: 2.0901e-04
# Epoch 76/100
# 60/60 [==============================] - 3s 43ms/step - loss: 4.9735e-05 - val_loss: 2.4941e-04
# Epoch 77/100
# 60/60 [==============================] - 3s 43ms/step - loss: 5.2236e-05 - val_loss: 2.1234e-04
# Epoch 78/100
# 60/60 [==============================] - 3s 42ms/step - loss: 4.7392e-05 - val_loss: 2.1277e-04
# Epoch 79/100
# 60/60 [==============================] - 3s 42ms/step - loss: 4.8182e-05 - val_loss: 2.0800e-04
# Epoch 80/100
# 60/60 [==============================] - 2s 42ms/step - loss: 5.2787e-05 - val_loss: 2.5446e-04
# Epoch 81/100
# 60/60 [==============================] - 3s 42ms/step - loss: 5.1126e-05 - val_loss: 2.0644e-04
# Epoch 82/100
# 60/60 [==============================] - 3s 42ms/step - loss: 5.3979e-05 - val_loss: 2.0618e-04
# Epoch 83/100
# 60/60 [==============================] - 2s 41ms/step - loss: 4.8370e-05 - val_loss: 2.3391e-04
# Epoch 84/100
# 60/60 [==============================] - 2s 42ms/step - loss: 5.0492e-05 - val_loss: 2.2006e-04
# Epoch 85/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.0186e-05 - val_loss: 2.2116e-04
# Epoch 86/100
# 60/60 [==============================] - 3s 42ms/step - loss: 4.7510e-05 - val_loss: 2.2713e-04
# Epoch 87/100
# 60/60 [==============================] - 2s 42ms/step - loss: 5.9844e-05 - val_loss: 2.9660e-04
# Epoch 88/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.0958e-05 - val_loss: 2.1139e-04
# Epoch 89/100
# 60/60 [==============================] - 2s 42ms/step - loss: 4.7872e-05 - val_loss: 2.6160e-04
# Epoch 90/100
# 60/60 [==============================] - 3s 42ms/step - loss: 4.7368e-05 - val_loss: 2.2034e-04
# Epoch 91/100
# 60/60 [==============================] - 2s 39ms/step - loss: 4.7743e-05 - val_loss: 2.2392e-04
# Epoch 92/100
# 60/60 [==============================] - 2s 41ms/step - loss: 6.0037e-05 - val_loss: 2.2138e-04
# Epoch 93/100
# 60/60 [==============================] - 2s 41ms/step - loss: 4.8721e-05 - val_loss: 2.3439e-04
# Epoch 94/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.1864e-05 - val_loss: 2.4707e-04
# Epoch 95/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.5133e-05 - val_loss: 2.4598e-04
# Epoch 96/100
# 60/60 [==============================] - 2s 41ms/step - loss: 4.6809e-05 - val_loss: 2.4107e-04
# Epoch 97/100
# 60/60 [==============================] - 2s 41ms/step - loss: 4.6491e-05 - val_loss: 2.1136e-04
# Epoch 98/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.4737e-05 - val_loss: 2.3325e-04
# Epoch 99/100
# 60/60 [==============================] - 2s 41ms/step - loss: 5.0657e-05 - val_loss: 3.0863e-04
# Epoch 100/100
# 60/60 [==============================] - 2s 40ms/step - loss: 5.2287e-05 - val_loss: 2.4554e-04

# %%
epochs = 50
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 60/60 [==============================] - 3s 44ms/step - loss: 4.7308e-05 - val_loss: 2.6217e-04
# Epoch 2/50
# 60/60 [==============================] - 3s 43ms/step - loss: 4.9122e-05 - val_loss: 2.1681e-04
# Epoch 3/50
# 60/60 [==============================] - 2s 39ms/step - loss: 4.4518e-05 - val_loss: 2.2490e-04
# Epoch 4/50
# 60/60 [==============================] - 2s 41ms/step - loss: 6.3745e-05 - val_loss: 2.3158e-04
# Epoch 5/50
# 60/60 [==============================] - 2s 41ms/step - loss: 6.5907e-05 - val_loss: 3.0027e-04
# Epoch 6/50
# 60/60 [==============================] - 2s 41ms/step - loss: 5.6730e-05 - val_loss: 2.2690e-04
# Epoch 7/50
# 60/60 [==============================] - 2s 41ms/step - loss: 4.7358e-05 - val_loss: 2.1375e-04
# Epoch 8/50
# 60/60 [==============================] - 3s 43ms/step - loss: 4.5716e-05 - val_loss: 2.6507e-04
# Epoch 9/50
# 60/60 [==============================] - 2s 41ms/step - loss: 5.0045e-05 - val_loss: 2.3940e-04
# Epoch 10/50
# 60/60 [==============================] - 2s 42ms/step - loss: 5.1812e-05 - val_loss: 2.2894e-04
# Epoch 11/50
# 60/60 [==============================] - 3s 42ms/step - loss: 5.1644e-05 - val_loss: 2.2900e-04
# Epoch 12/50
# 60/60 [==============================] - 2s 40ms/step - loss: 4.7419e-05 - val_loss: 2.2442e-04
# Epoch 13/50
# 60/60 [==============================] - 2s 41ms/step - loss: 5.4322e-05 - val_loss: 2.2228e-04
# Epoch 14/50
# 60/60 [==============================] - 2s 42ms/step - loss: 5.7040e-05 - val_loss: 2.1928e-04
# Epoch 15/50
# 60/60 [==============================] - 2s 42ms/step - loss: 5.1305e-05 - val_loss: 2.8122e-04
# Epoch 16/50
# 60/60 [==============================] - 3s 42ms/step - loss: 6.2137e-05 - val_loss: 3.6420e-04
# Epoch 17/50
# 60/60 [==============================] - 2s 42ms/step - loss: 5.2365e-05 - val_loss: 2.7294e-04
# Epoch 18/50
# 60/60 [==============================] - 3s 42ms/step - loss: 5.1549e-05 - val_loss: 2.1611e-04
# Epoch 19/50
# 60/60 [==============================] - 3s 43ms/step - loss: 4.5597e-05 - val_loss: 2.1380e-04
# Epoch 20/50
# 60/60 [==============================] - 3s 42ms/step - loss: 4.6574e-05 - val_loss: 2.1214e-04
# Epoch 21/50
# 60/60 [==============================] - 2s 42ms/step - loss: 4.5771e-05 - val_loss: 2.2080e-04
# Epoch 22/50
# 60/60 [==============================] - 2s 40ms/step - loss: 4.4468e-05 - val_loss: 2.1509e-04
# Epoch 23/50
# 60/60 [==============================] - 2s 40ms/step - loss: 4.5823e-05 - val_loss: 2.6183e-04
# Epoch 24/50
# 60/60 [==============================] - 2s 41ms/step - loss: 4.7492e-05 - val_loss: 2.2135e-04
# Epoch 25/50
# 60/60 [==============================] - 2s 41ms/step - loss: 4.5418e-05 - val_loss: 2.2388e-04
# Epoch 26/50
# 60/60 [==============================] - 2s 41ms/step - loss: 4.8400e-05 - val_loss: 2.1492e-04
# Epoch 27/50
# 60/60 [==============================] - 2s 42ms/step - loss: 5.0185e-05 - val_loss: 2.2329e-04
# Epoch 28/50
# 60/60 [==============================] - 2s 41ms/step - loss: 4.6534e-05 - val_loss: 2.3821e-04
# Epoch 29/50
# 60/60 [==============================] - 2s 42ms/step - loss: 4.5817e-05 - val_loss: 2.4371e-04
# Epoch 30/50
# 60/60 [==============================] - 2s 42ms/step - loss: 5.5346e-05 - val_loss: 2.1342e-04
# Epoch 31/50
# 60/60 [==============================] - 2s 40ms/step - loss: 4.8013e-05 - val_loss: 2.1982e-04
# Epoch 32/50
# 60/60 [==============================] - 2s 41ms/step - loss: 4.9498e-05 - val_loss: 2.3430e-04
# Epoch 33/50
# 60/60 [==============================] - 2s 40ms/step - loss: 4.4990e-05 - val_loss: 2.5218e-04
# Epoch 34/50
# 60/60 [==============================] - 2s 42ms/step - loss: 4.8469e-05 - val_loss: 2.1988e-04
# Epoch 35/50
# 60/60 [==============================] - 3s 42ms/step - loss: 5.2371e-05 - val_loss: 2.1558e-04
# Epoch 36/50
# 60/60 [==============================] - 3s 43ms/step - loss: 4.7313e-05 - val_loss: 2.1465e-04
# Epoch 37/50
# 60/60 [==============================] - 3s 42ms/step - loss: 4.9806e-05 - val_loss: 2.1606e-04
# Epoch 38/50
# 60/60 [==============================] - 2s 39ms/step - loss: 5.1875e-05 - val_loss: 2.6329e-04
# Epoch 39/50
# 60/60 [==============================] - 2s 39ms/step - loss: 4.6962e-05 - val_loss: 2.1548e-04
# Epoch 40/50
# 60/60 [==============================] - 2s 39ms/step - loss: 4.9478e-05 - val_loss: 2.1917e-04
# Epoch 41/50
# 60/60 [==============================] - 2s 40ms/step - loss: 4.5557e-05 - val_loss: 2.5044e-04
# Epoch 42/50
# 60/60 [==============================] - 2s 41ms/step - loss: 5.0828e-05 - val_loss: 2.1588e-04
# Epoch 43/50
# 60/60 [==============================] - 2s 42ms/step - loss: 4.7698e-05 - val_loss: 2.7504e-04
# Epoch 44/50
# 60/60 [==============================] - 2s 41ms/step - loss: 4.5731e-05 - val_loss: 2.1910e-04
# Epoch 45/50
# 60/60 [==============================] - 2s 40ms/step - loss: 4.8772e-05 - val_loss: 2.2339e-04
# Epoch 46/50
# 60/60 [==============================] - 2s 41ms/step - loss: 4.5825e-05 - val_loss: 2.1916e-04
# Epoch 47/50
# 60/60 [==============================] - 2s 40ms/step - loss: 4.5441e-05 - val_loss: 2.8429e-04
# Epoch 48/50
# 60/60 [==============================] - 2s 40ms/step - loss: 5.4324e-05 - val_loss: 2.1764e-04
# Epoch 49/50
# 60/60 [==============================] - 3s 42ms/step - loss: 5.2968e-05 - val_loss: 2.1951e-04
# Epoch 50/50
# 60/60 [==============================] - 2s 42ms/step - loss: 4.5306e-05 - val_loss: 2.1988e-04

# %%
y_pred = model.predict(X_test)

y_pred_inverse = scaler.inverse_transform(y_pred)
y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 15/15 [==============================] - 2s 12ms/step

# %%
rmse = np.sqrt(np.mean((y_pred_inverse - y_test_inverse) ** 2))
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 11.331769573682024

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index[train_size+window_size:], y_test_inverse, label='Actual Prices', color='blue')
plt.plot(data.index[train_size+window_size:], y_pred_inverse, label='Predicted Prices', color='red')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Stock Market Prediction using LSTM')
plt.legend()
plt.show()
